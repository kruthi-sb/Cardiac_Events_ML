# %%
import pandas as pd

# %%
d = pd.read_csv("C:\\Users\\kruth\\Desktop\\Cardiac\\Cardiac_Events_ML\\preprocessing\\inuse_processed_dataset.csv")

# %%
d.head()
# Out:
#    index   age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  \
# 0      0  63.0  1.0  3.0   145.0  233.0  1.0      0.0     150.0   0.0
# 1      1  37.0  1.0  2.0   130.0  250.0  0.0      1.0     187.0   0.0
# 2      2  41.0  0.0  1.0   130.0  204.0  0.0      0.0     172.0   0.0
# 3      3  56.0  1.0  1.0   120.0  236.0  0.0      1.0     178.0   0.0
# 4      4  57.0  0.0  0.0   120.0  354.0  0.0      1.0     163.0   1.0
#
#    oldpeak  slp  caa  thall  output Unnamed: 0
# 0      2.3  0.0  0.0    1.0     1.0      index
# 1      3.5  0.0  0.0    2.0     1.0      index
# 2      1.4  2.0  0.0    2.0     1.0      index
# 3      0.8  2.0  0.0    2.0     1.0      index
# 4      0.6  2.0  0.0    2.0     1.0      index
